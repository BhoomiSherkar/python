# %%
age = int(input("Enter your age:"))
if age >= 18:
    print("You can vote.")
else:
    print("You cannot vote.")

# %%
fruits = ["mango", "apple","banana"]
for fruit in fruits:
 print(fruit)

# %%
i = 1
while i <= 5:
  print(i)
  i += 1
